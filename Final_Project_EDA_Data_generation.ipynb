# %% [markdown]
# # Topic 2A: Climate and the Environment, General Measurements and Statistics
#
# # Project Purpose: We want to understand if we can predict air quality at a particular location based off of weather and greenhouse gas emissions in a specified radius of that location
#
# ## EDA

# %% [markdown]
# ## Important preliminary information:
# ### AQI is measured per specific pollutants, PM2.5, PM10, Ozone, CO, SO2, NO2. With the overall Daily AQI being the maximum value of any specific pollutant AQI.

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
#aqi_by_county = pd.read_csv("county_aqi_2020_daily.csv")
daily_global_weather_2020 = pd.read_csv("datasets/2020_daily_global_weather.csv").drop(columns="Unnamed: 0")
us_greenhouse_gas_emission_direct_emitter_gas_type = pd.read_csv("datasets/greenhouse_gas_emmiter_gas_types.csv", low_memory=False)

# %%
aqi_sites = pd.read_csv("datasets/aqs_sites.csv")

daily_county_aqi = pd.read_csv("datasets/county_aqi_2020_daily.csv") 

daily_temp = pd.read_csv("datasets/daily_temperature_2020.csv")

daily_wind = pd.read_csv("datasets/daily_wind_2020.csv")

traffic_volumes = pd.read_csv("datasets/traffic_volumes.csv")

# %% [markdown]
# ## "AQI by county" shows the annual distribution of AQI and ratings by State and County. Each row represents the AQI distribution of a State and County pair.
#
# ## "daily global weather 2020" shows the daily average temperature and precipitation on a global scale. Each row represents a specific station somewhere in the world per day.
#
# ## "US greenhouse gas emission" shows CO2 equivalent green house gas emissions for various greehhouse gasses by state, county, city and year. Each row represents a CO2 equivalent green house gas emission for a speific gas in a city by year.
#
# ## "aqi sites" has meta deta about the AQI sites where AQI values are measured and determined. Each row is a site.
#
# ## "daily_county_aqi" shows the daily AQI and its defining parameter for a State and County. Each row represents a day for each state and county pair.
#
# ## "daily_temp" shows the average daily temperature for a state and county. Each row represents a day for each state and county pair. (City column exists but does not apply to all rows)
#
# ## "daily_wind" shows the average wind speed and wind direction for a state and county. Each row represents a day for each state and county pair. (City column exists but does not apply to all rows)

# %%
# We want to predict the AQI column
daily_county_aqi
# Out:
#        State Name county Name  State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin           1            3  2020-01-01   48
# 1         Alabama     Baldwin           1            3  2020-01-04   13
# 2         Alabama     Baldwin           1            3  2020-01-07   14
# 3         Alabama     Baldwin           1            3  2020-01-10   39
# 4         Alabama     Baldwin           1            3  2020-01-13   29
# ...           ...         ...         ...          ...         ...  ...
# 336696    Wyoming      Weston          56           45  2020-12-27   32
# 336697    Wyoming      Weston          56           45  2020-12-28   30
# 336698    Wyoming      Weston          56           45  2020-12-29   33
# 336699    Wyoming      Weston          56           45  2020-12-30   33
# 336700    Wyoming      Weston          56           45  2020-12-31   34
#
#        Category Defining Parameter Defining Site  Number of Sites Reporting
# 0          Good              PM2.5   01-003-0010                          1
# 1          Good              PM2.5   01-003-0010                          1
# 2          Good              PM2.5   01-003-0010                          1
# 3          Good              PM2.5   01-003-0010                          1
# 4          Good              PM2.5   01-003-0010                          1
# ...         ...                ...           ...                        ...
# 336696     Good              Ozone   56-045-0003                          2
# 336697     Good              Ozone   56-045-0003                          2
# 336698     Good              Ozone   56-045-0003                          2
# 336699     Good              Ozone   56-045-0003                          2
# 336700     Good              Ozone   56-045-0003                          2
#
# [336701 rows x 10 columns]

# %% [markdown]
# ## Looking at the data sets, we have different granularities. For example, us_greenhouse_gas_emissions shows the ANNUAL CO2 equivalent emissions for a particular GH gas by State, County and City over multiple years. While the daily_no2, daily_so2, daily_co, daily_ozone, daily_temp, daily_wind, and daily_global_weather_2020 feature DAILY measurements over 1 year.
#
#
# ## Since we are trying to predict AQI, we should not include the values used to calculate the AQI found within daily_co, daily_ozone, daily_no2, daily_so2.
#
# ## Tentative Features to include in the model: daily_temp, daily_wind_speed, daily_wind_direction, daily_precipitation,  elevation, gh_gas_emissions by gas (co2 equivalents). Each row will be the daily value by each state and county.

# %%
#PRCP is average percipitation in tenths of a mm, TAVG is tempearture average at each station for each day
daily_global_weather_2020
# Out:
#              Station        Date   TAVG  Latitude  Longitude  Elevation   PRCP
# 0        AE000041196  2020-01-01  211.0   25.3330    55.5170       34.0    0.0
# 1        AEM00041194  2020-01-01  217.0   25.2550    55.3640       10.4    0.0
# 2        AFM00040938  2020-01-01   54.0   34.2100    62.2280      977.2   23.0
# 3        AG000060611  2020-01-01   71.0   28.0500     9.6331      561.0   10.0
# 4        AGE00147708  2020-01-01   99.0   36.7200     4.0500      222.0    0.0
# ...              ...         ...    ...       ...        ...        ...    ...
# 1064278  USW00094847  2020-10-22   96.0   42.2314   -83.3308      192.3  157.0
# 1064279  USW00094849  2020-10-22   67.0   45.0717   -83.5644      208.5   99.0
# 1064280  USW00094860  2020-10-22   77.0   42.8939   -85.5447      237.1  165.0
# 1064281  USW00094908  2020-10-22   73.0   42.3978   -90.7036      321.9  361.0
# 1064282  USW00094910  2020-10-22   70.0   42.5544   -92.4011      264.6  747.0
#
# [1064283 rows x 7 columns]

# %%
us_greenhouse_gas_emission_direct_emitter_gas_type.columns
# Out:
# Index(['V_GHG_EMITTER_GAS.ADDRESS1', 'V_GHG_EMITTER_GAS.ADDRESS2',
#        'V_GHG_EMITTER_GAS.CITY', 'V_GHG_EMITTER_GAS.CO2E_EMISSION',
#        'V_GHG_EMITTER_GAS.COUNTY', 'V_GHG_EMITTER_GAS.FACILITY_ID',
#        'V_GHG_EMITTER_GAS.GAS_CODE', 'V_GHG_EMITTER_GAS.GAS_NAME',
#        'V_GHG_EMITTER_GAS.LATITUDE', 'V_GHG_EMITTER_GAS.LONGITUDE',
#        'V_GHG_EMITTER_GAS.STATE', 'V_GHG_EMITTER_GAS.STATE_NAME',
#        'V_GHG_EMITTER_GAS.YEAR', 'V_GHG_EMITTER_GAS.ZIP',
#        'V_GHG_EMITTER_GAS.FACILITY_NAME', 'V_GHG_EMITTER_GAS.COUNTY_FIPS'],
#       dtype='object')

# %%
daily_county_aqi.columns
# Out:
# Index(['State Name', 'county Name', 'State Code', 'County Code', 'Date', 'AQI',
#        'Category', 'Defining Parameter', 'Defining Site',
#        'Number of Sites Reporting'],
#       dtype='object')

# %%
aqi_sites.columns
# Out:
# Index(['State Code', 'County Code', 'Site Number', 'Latitude', 'Longitude',
#        'Datum', 'Elevation', 'Land Use', 'Location Setting',
#        'Site Established Date', 'Site Closed Date', 'Met Site State Code',
#        'Met Site County Code', 'Met Site Site Number', 'Met Site Type',
#        'Met Site Distance', 'Met Site Direction', 'GMT Offset',
#        'Owning Agency', 'Local Site Name', 'Address', 'Zip Code', 'State Name',
#        'County Name', 'City Name', 'CBSA Name', 'Tribe Name',
#        'Extraction Date'],
#       dtype='object')

# %% [markdown]
# ## The defining site column in daily_county_aqi is defined by "State Code"-"County Code"-"Site Number" for a given State and County in aqi_sites. Thus, the City name can be determined by the defining site using the aqi_sites table, if increased granularity is required.

# %%
daily_wind.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Sample Duration',
#        'Pollutant Standard', 'Date Local', 'Units of Measure', 'Event Type',
#        'Observation Count', 'Observation Percent', 'Arithmetic Mean',
#        '1st Max Value', '1st Max Hour', 'AQI', 'Method Code', 'Method Name',
#        'Local Site Name', 'Address', 'State Name', 'County Name', 'City Name',
#        'CBSA Name', 'Date of Last Change'],
#       dtype='object')

# %%
daily_temp.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Sample Duration',
#        'Pollutant Standard', 'Date Local', 'Units of Measure', 'Event Type',
#        'Observation Count', 'Observation Percent', 'Arithmetic Mean',
#        '1st Max Value', '1st Max Hour', 'AQI', 'Method Code', 'Method Name',
#        'Local Site Name', 'Address', 'State Name', 'County Name', 'City Name',
#        'CBSA Name', 'Date of Last Change'],
#       dtype='object')

# %% [markdown]
# # Aggregating Daily temp, wind speed and wind direction by state and county

# %% [markdown]
# ## EDA on Daily Temperature Data

# %%
# EDA on daily temperature, wind speed and wind direction

# Extracting relevant columns
truncated_daily_temp = daily_temp[["State Code", "County Code", "Site Num", "State Name", "County Name", "City Name", "Latitude", "Longitude", "Date Local", "Arithmetic Mean"]]

# Array of US States and territories
US_States_territories = us_greenhouse_gas_emission_direct_emitter_gas_type["V_GHG_EMITTER_GAS.STATE_NAME"].unique()

# Only US States and territories should be in our data
truncated_daily_temp = truncated_daily_temp[truncated_daily_temp["State Name"].str.upper().isin(US_States_territories)]

# Impute missing 0s, with mean of the arithmetic mean, there are no null values
truncated_daily_temp["Arithmetic Mean"] = truncated_daily_temp["Arithmetic Mean"].replace(0, truncated_daily_temp["Arithmetic Mean"].mean())

# Rename Arithmetic Mean column to include temperature and units (Temp - F)
truncated_daily_temp = truncated_daily_temp.rename(columns={"Arithmetic Mean": "Mean Temperature (F)"})

# %%
truncated_daily_temp
# Out:
#         State Code  County Code  Site Num State Name County Name  \
# 0                1           53      1000    Alabama    Escambia
# 1                1           53      1000    Alabama    Escambia
# 2                1           53      1000    Alabama    Escambia
# 3                1           53      1000    Alabama    Escambia
# 4                1           53      1000    Alabama    Escambia
# ...            ...          ...       ...        ...         ...
# 290326          56           45       800    Wyoming      Weston
# 290327          56           45       800    Wyoming      Weston
# 290328          56           45       800    Wyoming      Weston
# 290329          56           45       800    Wyoming      Weston
# 290330          56           45       800    Wyoming      Weston
#
#             City Name  Latitude  Longitude  Date Local  Mean Temperature (F)
# 0       Not in a city  31.09210  -87.54350  2020-01-01             53.540000
# 1       Not in a city  31.09210  -87.54350  2020-01-02             67.342857
# 2       Not in a city  31.09210  -87.54350  2020-01-03             26.580000
# 3       Not in a city  31.09210  -87.54350  2020-01-04             44.830000
# 4       Not in a city  31.09210  -87.54350  2020-01-05             51.550000
# ...               ...       ...        ...         ...                   ...
# 290326      Newcastle  43.84539 -104.20512  2020-12-27             31.000000
# 290327      Newcastle  43.84539 -104.20512  2020-12-28             26.000000
# 290328      Newcastle  43.84539 -104.20512  2020-12-29             22.958333
# 290329      Newcastle  43.84539 -104.20512  2020-12-30             14.583333
# 290330      Newcastle  43.84539 -104.20512  2020-12-31             24.833333
#
# [290331 rows x 10 columns]

# %% [markdown]
# ## EDA on Daily Wind Data

# %%
# Extract relevant Columns
truncated_daily_wind = daily_wind[["State Code", "County Code", "Site Num", "State Name", "County Name", "City Name", "Latitude", "Longitude", "Parameter Name", "Date Local", "Arithmetic Mean"]]

# Only US States and territories should be in our data
truncated_daily_wind = truncated_daily_wind[truncated_daily_wind["State Name"].str.upper().isin(US_States_territories)]

# Seperate wind direction and wind speed before imputing missing values
daily_wind_speed = truncated_daily_wind[truncated_daily_wind["Parameter Name"] == "Wind Speed - Resultant"].reset_index(drop=True)

daily_wind_direction = truncated_daily_wind[truncated_daily_wind["Parameter Name"] == "Wind Direction - Resultant"].reset_index(drop=True)

# Impute missing values or 0 values with mean of the column
daily_wind_speed["Arithmetic Mean"] = daily_wind_speed["Arithmetic Mean"].replace(0, daily_wind_speed["Arithmetic Mean"].mean())

daily_wind_direction["Arithmetic Mean"] = daily_wind_direction["Arithmetic Mean"].replace(0, daily_wind_direction["Arithmetic Mean"].mean())

# Rename Arithmetic Mean columns to include the measurement and units
daily_wind_speed = daily_wind_speed.rename(columns={"Arithmetic Mean": "Mean Wind Speed (knots)"}).drop(columns=["Parameter Name"])
daily_wind_direction = daily_wind_direction.rename(columns={"Arithmetic Mean": "Mean Wind Direction (compass degrees)"}).drop(columns=["Parameter Name"])

# %%
daily_wind_speed
# Out:
#         State Code  County Code  Site Num State Name County Name  \
# 0                1           53      1000    Alabama    Escambia
# 1                1           53      1000    Alabama    Escambia
# 2                1           53      1000    Alabama    Escambia
# 3                1           53      1000    Alabama    Escambia
# 4                1           53      1000    Alabama    Escambia
# ...            ...          ...       ...        ...         ...
# 239426          56           39      1013    Wyoming       Teton
# 239427          56           39      1013    Wyoming       Teton
# 239428          56           39      1013    Wyoming       Teton
# 239429          56           39      1013    Wyoming       Teton
# 239430          56           39      1013    Wyoming       Teton
#
#             City Name   Latitude   Longitude  Date Local  \
# 0       Not in a city  31.092100  -87.543500  2020-01-01
# 1       Not in a city  31.092100  -87.543500  2020-01-02
# 2       Not in a city  31.092100  -87.543500  2020-01-03
# 3       Not in a city  31.092100  -87.543500  2020-01-04
# 4       Not in a city  31.092100  -87.543500  2020-01-05
# ...               ...        ...         ...         ...
# 239426  Not in a city  44.373056 -110.830833  2020-12-27
# 239427  Not in a city  44.373056 -110.830833  2020-12-28
# 239428  Not in a city  44.373056 -110.830833  2020-12-29
# 239429  Not in a city  44.373056 -110.830833  2020-12-30
# 239430  Not in a city  44.373056 -110.830833  2020-12-31
#
#         Mean Wind Speed (knots)
# 0                      4.349492
# 1                      4.349492
# 2                      4.349492
# 3                      4.349492
# 4                      4.349492
# ...                         ...
# 239426                 1.795833
# 239427                 1.212500
# 239428                 1.441667
# 239429                 1.466667
# 239430                 1.687500
#
# [239431 rows x 10 columns]

# %%
daily_wind_direction
# Out:
#         State Code  County Code  Site Num State Name County Name  \
# 0                1           53      1000    Alabama    Escambia
# 1                1           53      1000    Alabama    Escambia
# 2                1           53      1000    Alabama    Escambia
# 3                1           53      1000    Alabama    Escambia
# 4                1           53      1000    Alabama    Escambia
# ...            ...          ...       ...        ...         ...
# 242333          56           39      1013    Wyoming       Teton
# 242334          56           39      1013    Wyoming       Teton
# 242335          56           39      1013    Wyoming       Teton
# 242336          56           39      1013    Wyoming       Teton
# 242337          56           39      1013    Wyoming       Teton
#
#             City Name   Latitude   Longitude  Date Local  \
# 0       Not in a city  31.092100  -87.543500  2020-01-01
# 1       Not in a city  31.092100  -87.543500  2020-01-02
# 2       Not in a city  31.092100  -87.543500  2020-01-03
# 3       Not in a city  31.092100  -87.543500  2020-01-04
# 4       Not in a city  31.092100  -87.543500  2020-01-05
# ...               ...        ...         ...         ...
# 242333  Not in a city  44.373056 -110.830833  2020-12-27
# 242334  Not in a city  44.373056 -110.830833  2020-12-28
# 242335  Not in a city  44.373056 -110.830833  2020-12-29
# 242336  Not in a city  44.373056 -110.830833  2020-12-30
# 242337  Not in a city  44.373056 -110.830833  2020-12-31
#
#         Mean Wind Direction (compass degrees)
# 0                                  179.900000
# 1                                  108.857143
# 2                                  271.000000
# 3                                  230.100000
# 4                                  251.100000
# ...                                       ...
# 242333                             190.375000
# 242334                             171.375000
# 242335                             181.166667
# 242336                             173.666667
# 242337                             157.958333
#
# [242338 rows x 10 columns]

# %% [markdown]
# ## Merging the wind, and temperature data

# %%
wind_data_merge = pd.merge(daily_wind_direction, daily_wind_speed, how='inner', on=["State Code", "County Code", "Site Num", "State Name", "County Name", "City Name", "Latitude", "Longitude", "Date Local"])

# %%
weather_data = truncated_daily_temp.merge(wind_data_merge, how='inner', on=["State Code", "County Code", "Site Num", "State Name", "County Name", "City Name", "Latitude", "Longitude", "Date Local"])

# %% [markdown]
# ## Final dataset which includes weather data

# %%
weather_data
# Out:
#         State Code  County Code  Site Num State Name County Name  \
# 0                1           53      1000    Alabama    Escambia
# 1                1           53      1000    Alabama    Escambia
# 2                1           53      1000    Alabama    Escambia
# 3                1           53      1000    Alabama    Escambia
# 4                1           53      1000    Alabama    Escambia
# ...            ...          ...       ...        ...         ...
# 228161          56           39      1013    Wyoming       Teton
# 228162          56           39      1013    Wyoming       Teton
# 228163          56           39      1013    Wyoming       Teton
# 228164          56           39      1013    Wyoming       Teton
# 228165          56           39      1013    Wyoming       Teton
#
#             City Name   Latitude   Longitude  Date Local  \
# 0       Not in a city  31.092100  -87.543500  2020-01-01
# 1       Not in a city  31.092100  -87.543500  2020-01-02
# 2       Not in a city  31.092100  -87.543500  2020-01-03
# 3       Not in a city  31.092100  -87.543500  2020-01-04
# 4       Not in a city  31.092100  -87.543500  2020-01-05
# ...               ...        ...         ...         ...
# 228161  Not in a city  44.373056 -110.830833  2020-12-27
# 228162  Not in a city  44.373056 -110.830833  2020-12-28
# 228163  Not in a city  44.373056 -110.830833  2020-12-29
# 228164  Not in a city  44.373056 -110.830833  2020-12-30
# 228165  Not in a city  44.373056 -110.830833  2020-12-31
#
#         Mean Temperature (F)  Mean Wind Direction (compass degrees)  \
# 0                  53.540000                             179.900000
# 1                  67.342857                             108.857143
# 2                  26.580000                             271.000000
# 3                  44.830000                             230.100000
# 4                  51.550000                             251.100000
# ...                      ...                                    ...
# 228161             15.250000                             190.375000
# 228162             -4.833333                             171.375000
# 228163             -1.625000                             181.166667
# 228164              8.291667                             173.666667
# 228165             18.875000                             157.958333
#
#         Mean Wind Speed (knots)
# 0                      4.349492
# 1                      4.349492
# 2                      4.349492
# 3                      4.349492
# 4                      4.349492
# ...                         ...
# 228161                 1.795833
# 228162                 1.212500
# 228163                 1.441667
# 228164                 1.466667
# 228165                 1.687500
#
# [228166 rows x 12 columns]

# %%
len(weather_data["City Name"].unique())
# Out:
# 368

# %% [markdown]
# # Incorporating land use, elevation and location setting for the AQI sites into weather data set as features

# %%
truncated_aqi_sites = aqi_sites[["State Code", "County Code", "Site Number", "State Name", "County Name", "City Name", "Elevation", "Land Use", "Location Setting"]].rename(columns={"Site Number": "Site Num"})

# Only showing US and territories aqi sites
truncated_aqi_sites = truncated_aqi_sites[truncated_aqi_sites["State Name"].str.upper().isin(US_States_territories)]

truncated_aqi_sites["State Code"] = truncated_aqi_sites["State Code"].astype(int)

# %%
truncated_aqi_sites[(truncated_aqi_sites["State Name"] == "Alabama") & (truncated_aqi_sites["County Name"] == "Escambia")]
# Out:
#     State Code  County Code  Site Num State Name County Name      City Name  \
# 80           1           53         1    Alabama    Escambia        Brewton
# 81           1           53         2    Alabama    Escambia        Brewton
# 82           1           53      1000    Alabama    Escambia  Not in a City
#
#     Elevation      Land Use       Location Setting
# 80      37.00   RESIDENTIAL               SUBURBAN
# 81      50.00    COMMERCIAL  URBAN AND CENTER CITY
# 82      89.61  AGRICULTURAL                  RURAL

# %%
feature_set = weather_data.merge(truncated_aqi_sites, on=["State Code", "County Code", "Site Num"])

# %%
feature_set = feature_set.drop(columns=["State Name_y", "County Name_y", "City Name_y"]).rename(columns={"State Name_x": "State Name", "County Name_x": "County Name", "City Name_x": "City Name"})

# %%
feature_set
# Out:
#         State Code  County Code  Site Num State Name County Name  \
# 0                1           53      1000    Alabama    Escambia
# 1                1           53      1000    Alabama    Escambia
# 2                1           53      1000    Alabama    Escambia
# 3                1           53      1000    Alabama    Escambia
# 4                1           53      1000    Alabama    Escambia
# ...            ...          ...       ...        ...         ...
# 228161          56           39      1013    Wyoming       Teton
# 228162          56           39      1013    Wyoming       Teton
# 228163          56           39      1013    Wyoming       Teton
# 228164          56           39      1013    Wyoming       Teton
# 228165          56           39      1013    Wyoming       Teton
#
#             City Name   Latitude   Longitude  Date Local  \
# 0       Not in a city  31.092100  -87.543500  2020-01-01
# 1       Not in a city  31.092100  -87.543500  2020-01-02
# 2       Not in a city  31.092100  -87.543500  2020-01-03
# 3       Not in a city  31.092100  -87.543500  2020-01-04
# 4       Not in a city  31.092100  -87.543500  2020-01-05
# ...               ...        ...         ...         ...
# 228161  Not in a city  44.373056 -110.830833  2020-12-27
# 228162  Not in a city  44.373056 -110.830833  2020-12-28
# 228163  Not in a city  44.373056 -110.830833  2020-12-29
# 228164  Not in a city  44.373056 -110.830833  2020-12-30
# 228165  Not in a city  44.373056 -110.830833  2020-12-31
#
#         Mean Temperature (F)  Mean Wind Direction (compass degrees)  \
# 0                  53.540000                             179.900000
# 1                  67.342857                             108.857143
# 2                  26.580000                             271.000000
# 3                  44.830000                             230.100000
# 4                  51.550000                             251.100000
# ...                      ...                                    ...
# 228161             15.250000                             190.375000
# 228162             -4.833333                             171.375000
# 228163             -1.625000                             181.166667
# 228164              8.291667                             173.666667
# 228165             18.875000                             157.958333
#
#         Mean Wind Speed (knots)  Elevation      Land Use Location Setting
# 0                      4.349492      89.61  AGRICULTURAL            RURAL
# 1                      4.349492      89.61  AGRICULTURAL            RURAL
# 2                      4.349492      89.61  AGRICULTURAL            RURAL
# 3                      4.349492      89.61  AGRICULTURAL            RURAL
# 4                      4.349492      89.61  AGRICULTURAL            RURAL
# ...                         ...        ...           ...              ...
# 228161                 1.795833    2230.00        FOREST            RURAL
# 228162                 1.212500    2230.00        FOREST            RURAL
# 228163                 1.441667    2230.00        FOREST            RURAL
# 228164                 1.466667    2230.00        FOREST            RURAL
# 228165                 1.687500    2230.00        FOREST            RURAL
#
# [228166 rows x 15 columns]

# %% [markdown]
# ## Adding the observed values for AQI to the features dataset

# %%
## Extracting the Site Num from Defining Site
daily_county_aqi["Site Num"] = daily_county_aqi["Defining Site"].str.extract(pat=f'\d+-\d+-(\d+)').astype(int)

# %%
## Renaming columns to allow for merge
daily_county_aqi = daily_county_aqi.rename(columns={"county Name": "County Name", "Date": "Date Local"})

# %%
## Merging with the feature set
final_data_set = feature_set.merge(daily_county_aqi, on=["State Code", "County Code", "Site Num", "Date Local"])

# %%
## Dropping redundant columns and renaming 
final_data_set = final_data_set.drop(columns=["State Name_y", "County Name_y"]).rename(columns={"State Name_x": "State Name", "County Name_x":"County Name"})

# %%
final_data_set
# Out:
#        State Code  County Code  Site Num State Name County Name  \
# 0               1           73        23    Alabama   Jefferson
# 1               1           73        23    Alabama   Jefferson
# 2               1           73        23    Alabama   Jefferson
# 3               1           73        23    Alabama   Jefferson
# 4               1           73        23    Alabama   Jefferson
# ...           ...          ...       ...        ...         ...
# 94814          56           39      1013    Wyoming       Teton
# 94815          56           39      1013    Wyoming       Teton
# 94816          56           39      1013    Wyoming       Teton
# 94817          56           39      1013    Wyoming       Teton
# 94818          56           39      1013    Wyoming       Teton
#
#            City Name   Latitude   Longitude  Date Local  Mean Temperature (F)  \
# 0         Birmingham  33.553056  -86.815000  2020-01-09             52.125000
# 1         Birmingham  33.553056  -86.815000  2020-01-10             65.750000
# 2         Birmingham  33.553056  -86.815000  2020-01-14             63.937500
# 3         Birmingham  33.553056  -86.815000  2020-01-16             58.012500
# 4         Birmingham  33.553056  -86.815000  2020-01-17             54.945833
# ...              ...        ...         ...         ...                   ...
# 94814  Not in a city  44.373056 -110.830833  2020-10-05             45.708333
# 94815  Not in a city  44.373056 -110.830833  2020-10-07             44.083333
# 94816  Not in a city  44.373056 -110.830833  2020-10-08             46.375000
# 94817  Not in a city  44.373056 -110.830833  2020-10-09             45.041667
# 94818  Not in a city  44.373056 -110.830833  2020-10-10             43.875000
#
#        Mean Wind Direction (compass degrees)  Mean Wind Speed (knots)  \
# 0                                 137.125000                 4.904167
# 1                                 163.708333                 7.583333
# 2                                 208.916667                 3.166667
# 3                                  75.458333                 5.945833
# 4                                 105.375000                 5.491667
# ...                                      ...                      ...
# 94814                             162.666667                 2.287500
# 94815                             174.791667                 2.087500
# 94816                             169.375000                 3.016667
# 94817                             168.666667                 2.612500
# 94818                             191.791667                 4.179167
#
#        Elevation    Land Use       Location Setting  AQI  Category  \
# 0          177.0  COMMERCIAL  URBAN AND CENTER CITY   56  Moderate
# 1          177.0  COMMERCIAL  URBAN AND CENTER CITY   44      Good
# 2          177.0  COMMERCIAL  URBAN AND CENTER CITY   30      Good
# 3          177.0  COMMERCIAL  URBAN AND CENTER CITY   31      Good
# 4          177.0  COMMERCIAL  URBAN AND CENTER CITY   34      Good
# ...          ...         ...                    ...  ...       ...
# 94814     2230.0      FOREST                  RURAL   54  Moderate
# 94815     2230.0      FOREST                  RURAL   85  Moderate
# 94816     2230.0      FOREST                  RURAL   69  Moderate
# 94817     2230.0      FOREST                  RURAL   55  Moderate
# 94818     2230.0      FOREST                  RURAL   70  Moderate
#
#       Defining Parameter Defining Site  Number of Sites Reporting
# 0                  PM2.5   01-073-0023                          9
# 1                  PM2.5   01-073-0023                          9
# 2                    NO2   01-073-0023                          9
# 3                  Ozone   01-073-0023                          9
# 4                  Ozone   01-073-0023                          8
# ...                  ...           ...                        ...
# 94814              PM2.5   56-039-1013                          3
# 94815              PM2.5   56-039-1013                          3
# 94816              PM2.5   56-039-1013                          3
# 94817              PM2.5   56-039-1013                          4
# 94818              PM2.5   56-039-1013                          3
#
# [94819 rows x 20 columns]

# %% [markdown]
# # US Emissions data set
# ## Incorporating US GH emissions by state/county as features

# %%
us_greenhouse_gas_emission_direct_emitter_gas_type.columns
# Out:
# Index(['V_GHG_EMITTER_GAS.ADDRESS1', 'V_GHG_EMITTER_GAS.ADDRESS2',
#        'V_GHG_EMITTER_GAS.CITY', 'V_GHG_EMITTER_GAS.CO2E_EMISSION',
#        'V_GHG_EMITTER_GAS.COUNTY', 'V_GHG_EMITTER_GAS.FACILITY_ID',
#        'V_GHG_EMITTER_GAS.GAS_CODE', 'V_GHG_EMITTER_GAS.GAS_NAME',
#        'V_GHG_EMITTER_GAS.LATITUDE', 'V_GHG_EMITTER_GAS.LONGITUDE',
#        'V_GHG_EMITTER_GAS.STATE', 'V_GHG_EMITTER_GAS.STATE_NAME',
#        'V_GHG_EMITTER_GAS.YEAR', 'V_GHG_EMITTER_GAS.ZIP',
#        'V_GHG_EMITTER_GAS.FACILITY_NAME', 'V_GHG_EMITTER_GAS.COUNTY_FIPS'],
#       dtype='object')

# %%
us_greenhouse_gas_emission_direct_emitter_gas_type
# Out:
#        V_GHG_EMITTER_GAS.ADDRESS1  V_GHG_EMITTER_GAS.ADDRESS2  \
# 0                1919 S. BROADWAY                         NaN
# 1                    850 12TH AVE                         NaN
# 2                    3379 HWY 482                         NaN
# 3               1012 BEAUCHAMP ST                         NaN
# 4             487 CORN CREEK ROAD                         NaN
# ...                           ...                         ...
# 219923       14353 McFarland Road                         NaN
# 219924        7628 Thorndike Road                         NaN
# 219925                        NaN                         NaN
# 219926            1186 Calkins Rd                         NaN
# 219927            1186 Calkins Rd                         NaN
#
#        V_GHG_EMITTER_GAS.CITY  V_GHG_EMITTER_GAS.CO2E_EMISSION  \
# 0                   GREEN BAY                        58024.000
# 1                    NEW YORK                          134.500
# 2                       Noble                            6.854
# 3                  GREENVILLE                        53562.000
# 4                     BEDFORD                      7635064.700
# ...                       ...                              ...
# 219923             Burlington                         1929.800
# 219924             Greensboro                         2776.500
# 219925                Calumet                        28352.800
# 219926                   Troy                           23.840
# 219927                   Troy                           23.000
#
#        V_GHG_EMITTER_GAS.COUNTY  V_GHG_EMITTER_GAS.FACILITY_ID  \
# 0                  BROWN COUNTY                        1000589
# 1                      New York                        1000766
# 2                        SABINE                        1009343
# 3             WASHINGTON COUNTY                        1003557
# 4                       Trimble                        1006542
# ...                         ...                            ...
# 219923            SKAGIT COUNTY                        1010898
# 219924          GUILFORD COUNTY                        1010033
# 219925          CANADIAN COUNTY                        1011778
# 219926                 BRADFORD                        1010571
# 219927          BRADFORD COUNTY                        1010571
#
#        V_GHG_EMITTER_GAS.GAS_CODE V_GHG_EMITTER_GAS.GAS_NAME  \
# 0                          BIOCO2               Biogenic CO2
# 1                             CH4                    Methane
# 2                             N2O              Nitrous Oxide
# 3                             CH4                    Methane
# 4                             CO2             Carbon Dioxide
# ...                           ...                        ...
# 219923                        CO2             Carbon Dioxide
# 219924                        CO2             Carbon Dioxide
# 219925                        CO2             Carbon Dioxide
# 219926                        N2O              Nitrous Oxide
# 219927                        CH4                    Methane
#
#         V_GHG_EMITTER_GAS.LATITUDE  V_GHG_EMITTER_GAS.LONGITUDE  \
# 0                        44.492500                   -88.032300
# 1                        40.771100                   -73.991100
# 2                        31.621528                   -93.724774
# 3                        33.392476                   -91.017584
# 4                        38.584700                   -85.411700
# ...                            ...                          ...
# 219923                   48.448041                  -122.433615
# 219924                   36.075650                   -79.965030
# 219925                   35.516370                   -98.182280
# 219926                   41.730488                   -76.707873
# 219927                   41.730488                   -76.707873
#
#        V_GHG_EMITTER_GAS.STATE V_GHG_EMITTER_GAS.STATE_NAME  \
# 0                           WI                    WISCONSIN
# 1                           NY                     NEW YORK
# 2                           LA                    LOUISIANA
# 3                           MS                  MISSISSIPPI
# 4                           KY                     KENTUCKY
# ...                        ...                          ...
# 219923                      WA                   WASHINGTON
# 219924                      NC               NORTH CAROLINA
# 219925                      OK                     OKLAHOMA
# 219926                      PA                 PENNSYLVANIA
# 219927                      PA                 PENNSYLVANIA
#
#         V_GHG_EMITTER_GAS.YEAR  V_GHG_EMITTER_GAS.ZIP  \
# 0                         2017                  54304
# 1                         2018                  10019
# 2                         2012                  71462
# 3                         2017                  38701
# 4                         2018                  40006
# ...                        ...                    ...
# 219923                    2016                  98273
# 219924                    2018                  27409
# 219925                    2014                  73014
# 219926                    2012                  16947
# 219927                    2013                  16947
#
#                     V_GHG_EMITTER_GAS.FACILITY_NAME  \
# 0           GEORGIA-PACIFIC CONSUMER OPERATIONS LLC
# 1                                       59th Street
# 2                                Baker Road Treater
# 3       TEXAS GAS TRANSMISSION - GREENVILLE STATION
# 4                                    Trimble County
# ...                                             ...
# 219923       Sierra Pacific Industries - Burlington
# 219924                                        QORVO
# 219925                            OFS CS Cedar Lake
# 219926                 Granville Compressor Station
# 219927                 Granville Compressor Station
#
#         V_GHG_EMITTER_GAS.COUNTY_FIPS
# 0                             55009.0
# 1                             36061.0
# 2                             22085.0
# 3                             28151.0
# 4                             21223.0
# ...                               ...
# 219923                        53057.0
# 219924                        37081.0
# 219925                        40017.0
# 219926                        42015.0
# 219927                        42015.0
#
# [219928 rows x 16 columns]

# %%
US_GH_gas_emissions = us_greenhouse_gas_emission_direct_emitter_gas_type[["V_GHG_EMITTER_GAS.STATE_NAME", "V_GHG_EMITTER_GAS.COUNTY", "V_GHG_EMITTER_GAS.CITY", "V_GHG_EMITTER_GAS.CO2E_EMISSION", "V_GHG_EMITTER_GAS.GAS_CODE", "V_GHG_EMITTER_GAS.GAS_NAME", "V_GHG_EMITTER_GAS.YEAR"]]

# %%
pd.options.mode.chained_assignment = None

# Renaming columns and making sure the names match with the final_data set we will eventually merge with.
US_GH_gas_emissions.columns = ["State Name", "County Name", "City Name", "CO2 equiv emission", "Gas Code", "Gas Name", "Year"]
US_GH_gas_emissions["State Name"] = US_GH_gas_emissions["State Name"].str.title()
US_GH_gas_emissions["County Name"] = US_GH_gas_emissions["County Name"].str.title()
US_GH_gas_emissions["City Name"] = US_GH_gas_emissions["City Name"].str.title()

# %%
US_GH_gas_emissions
# Out:
#             State Name        County Name   City Name  CO2 equiv emission  \
# 0            Wisconsin       Brown County   Green Bay           58024.000
# 1             New York           New York    New York             134.500
# 2            Louisiana             Sabine       Noble               6.854
# 3          Mississippi  Washington County  Greenville           53562.000
# 4             Kentucky            Trimble     Bedford         7635064.700
# ...                ...                ...         ...                 ...
# 219923      Washington      Skagit County  Burlington            1929.800
# 219924  North Carolina    Guilford County  Greensboro            2776.500
# 219925        Oklahoma    Canadian County     Calumet           28352.800
# 219926    Pennsylvania           Bradford        Troy              23.840
# 219927    Pennsylvania    Bradford County        Troy              23.000
#
#        Gas Code        Gas Name  Year
# 0        BIOCO2    Biogenic CO2  2017
# 1           CH4         Methane  2018
# 2           N2O   Nitrous Oxide  2012
# 3           CH4         Methane  2017
# 4           CO2  Carbon Dioxide  2018
# ...         ...             ...   ...
# 219923      CO2  Carbon Dioxide  2016
# 219924      CO2  Carbon Dioxide  2018
# 219925      CO2  Carbon Dioxide  2014
# 219926      N2O   Nitrous Oxide  2012
# 219927      CH4         Methane  2013
#
# [219928 rows x 7 columns]

# %%
Grouped_US_GH_gas_emissions = US_GH_gas_emissions.groupby(["State Name", "County Name", "City Name", "Gas Code"])["CO2 equiv emission"].agg("mean").reset_index()

# %%
# CO2 equiv emissions are the average annual CO2 equiv emissions for the gas.
Grouped_US_GH_gas_emissions
# Out:
#       State Name    County Name     City Name Gas Code  CO2 equiv emission
# 0        Alabama        Autauga  Autaugaville      CH4        9.502500e+02
# 1        Alabama        Autauga  Autaugaville      CO2        2.049189e+06
# 2        Alabama        Autauga  Autaugaville      N2O        1.132698e+03
# 3        Alabama        Autauga   Billingsley      CH4        6.356875e+02
# 4        Alabama        Autauga   Billingsley      CO2        1.375766e+06
# ...          ...            ...           ...      ...                 ...
# 23017    Wyoming         Weston         Osage      CO2        7.340513e+04
# 23018    Wyoming         Weston         Osage      N2O        1.081740e+03
# 23019    Wyoming  Weston County     Newcastle      CH4        1.263103e+03
# 23020    Wyoming  Weston County     Newcastle      CO2        9.864694e+04
# 23021    Wyoming  Weston County     Newcastle      N2O        2.266904e+02
#
# [23022 rows x 5 columns]

# %%
# Convert to daily GH gas emissions
Grouped_US_GH_gas_emissions["Average Daily CO2 equiv emission"] = Grouped_US_GH_gas_emissions["CO2 equiv emission"] / 366

# %%
Grouped_US_GH_gas_emissions = Grouped_US_GH_gas_emissions.drop(columns="CO2 equiv emission")

# %%
Grouped_US_GH_gas_emissions
# Out:
#       State Name    County Name     City Name Gas Code  \
# 0        Alabama        Autauga  Autaugaville      CH4
# 1        Alabama        Autauga  Autaugaville      CO2
# 2        Alabama        Autauga  Autaugaville      N2O
# 3        Alabama        Autauga   Billingsley      CH4
# 4        Alabama        Autauga   Billingsley      CO2
# ...          ...            ...           ...      ...
# 23017    Wyoming         Weston         Osage      CO2
# 23018    Wyoming         Weston         Osage      N2O
# 23019    Wyoming  Weston County     Newcastle      CH4
# 23020    Wyoming  Weston County     Newcastle      CO2
# 23021    Wyoming  Weston County     Newcastle      N2O
#
#        Average Daily CO2 equiv emission
# 0                              2.596311
# 1                           5598.875820
# 2                              3.094803
# 3                              1.736851
# 4                           3758.924495
# ...                                 ...
# 23017                        200.560474
# 23018                          2.955574
# 23019                          3.451101
# 23020                        269.527162
# 23021                          0.619373
#
# [23022 rows x 5 columns]

# %%
Pivot_Grouped_US_GH_gas_emissions = Grouped_US_GH_gas_emissions.pivot_table('Average Daily CO2 equiv emission', ["State Name", "County Name", "City Name"], "Gas Code").reset_index()

# %%
Pivot_Grouped_US_GH_gas_emissions
# Out:
# Gas Code State Name      County Name      City Name       BIOCO2         CH4  \
# 0           Alabama          Autauga   Autaugaville          NaN    2.596311
# 1           Alabama          Autauga    Billingsley          NaN    1.736851
# 2           Alabama          Autauga     Prattville  4362.405137   72.520516
# 3           Alabama   Baldwin County     Summerdale          NaN  499.213388
# 4           Alabama   Barbour County        Eufaula          NaN    0.055024
# ...             ...              ...            ...          ...         ...
# 7672        Wyoming     Uinta County  Mountain View          NaN    5.354679
# 7673        Wyoming         Washakie        Worland          NaN    0.038934
# 7674        Wyoming  Washakie County        Worland          NaN    0.047558
# 7675        Wyoming           Weston          Osage          NaN    0.155055
# 7676        Wyoming    Weston County      Newcastle          NaN    3.451101
#
# Gas Code          CO2  HFC  HFE        N2O  NF3  Other  Other_Full  PFC  SF6  \
# 0         5598.875820  NaN  NaN   3.094803  NaN    NaN         NaN  NaN  NaN
# 1         3758.924495  NaN  NaN   2.072728  NaN    NaN         NaN  NaN  NaN
# 2          860.282705  NaN  NaN  31.186514  NaN    NaN         NaN  NaN  NaN
# 3                 NaN  NaN  NaN        NaN  NaN    NaN         NaN  NaN  NaN
# 4          105.047787  NaN  NaN   0.065589  NaN    NaN         NaN  NaN  NaN
# ...               ...  ...  ...        ...  ...    ...         ...  ...  ...
# 7672        36.397404  NaN  NaN   0.019948  NaN    NaN         NaN  NaN  NaN
# 7673        66.135656  NaN  NaN   0.054552  NaN    NaN         NaN  NaN  NaN
# 7674        79.295663  NaN  NaN   0.067885  NaN    NaN         NaN  NaN  NaN
# 7675       200.560474  NaN  NaN   2.955574  NaN    NaN         NaN  NaN  NaN
# 7676       269.527162  NaN  NaN   0.619373  NaN    NaN         NaN  NaN  NaN
#
# Gas Code  Very_Short
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 7672             NaN
# 7673             NaN
# 7674             NaN
# 7675             NaN
# 7676             NaN
#
# [7677 rows x 15 columns]

# %%
# Resetting index
Pivot_Grouped_US_GH_gas_emissions = Pivot_Grouped_US_GH_gas_emissions.rename_axis(None, axis=1)

# %%
Pivot_Grouped_US_GH_gas_emissions
# Out:
#      State Name      County Name      City Name       BIOCO2         CH4  \
# 0       Alabama          Autauga   Autaugaville          NaN    2.596311
# 1       Alabama          Autauga    Billingsley          NaN    1.736851
# 2       Alabama          Autauga     Prattville  4362.405137   72.520516
# 3       Alabama   Baldwin County     Summerdale          NaN  499.213388
# 4       Alabama   Barbour County        Eufaula          NaN    0.055024
# ...         ...              ...            ...          ...         ...
# 7672    Wyoming     Uinta County  Mountain View          NaN    5.354679
# 7673    Wyoming         Washakie        Worland          NaN    0.038934
# 7674    Wyoming  Washakie County        Worland          NaN    0.047558
# 7675    Wyoming           Weston          Osage          NaN    0.155055
# 7676    Wyoming    Weston County      Newcastle          NaN    3.451101
#
#               CO2  HFC  HFE        N2O  NF3  Other  Other_Full  PFC  SF6  \
# 0     5598.875820  NaN  NaN   3.094803  NaN    NaN         NaN  NaN  NaN
# 1     3758.924495  NaN  NaN   2.072728  NaN    NaN         NaN  NaN  NaN
# 2      860.282705  NaN  NaN  31.186514  NaN    NaN         NaN  NaN  NaN
# 3             NaN  NaN  NaN        NaN  NaN    NaN         NaN  NaN  NaN
# 4      105.047787  NaN  NaN   0.065589  NaN    NaN         NaN  NaN  NaN
# ...           ...  ...  ...        ...  ...    ...         ...  ...  ...
# 7672    36.397404  NaN  NaN   0.019948  NaN    NaN         NaN  NaN  NaN
# 7673    66.135656  NaN  NaN   0.054552  NaN    NaN         NaN  NaN  NaN
# 7674    79.295663  NaN  NaN   0.067885  NaN    NaN         NaN  NaN  NaN
# 7675   200.560474  NaN  NaN   2.955574  NaN    NaN         NaN  NaN  NaN
# 7676   269.527162  NaN  NaN   0.619373  NaN    NaN         NaN  NaN  NaN
#
#       Very_Short
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 7672         NaN
# 7673         NaN
# 7674         NaN
# 7675         NaN
# 7676         NaN
#
# [7677 rows x 15 columns]

# %%
# Get number of non null entires (to see which gasses to add to the data set)
Pivot_Grouped_US_GH_gas_emissions.count()
# Out:
# State Name     7677
# County Name    7677
# City Name      7677
# BIOCO2         1360
# CH4            7599
# CO2            6908
# HFC              91
# HFE              36
# N2O            6507
# NF3              63
# Other            17
# Other_Full       69
# PFC              96
# SF6             226
# Very_Short       50
# dtype: int64

# %% [markdown]
# ## Based on the counts of non null entries, we have a reasonable amount of data for BIOCO2, CH4, CO2, and N2O. So we will try to use these as features. We can revist this if need be.

# %%
# Truncating data to the gasses we want and filling the NaN with 0s
Truncated_US_GH_gas_emissions = Pivot_Grouped_US_GH_gas_emissions[["State Name", "County Name", "City Name", "BIOCO2", "CH4", "CO2", "N2O"]].fillna(0)

# %%
Truncated_US_GH_gas_emissions
# Out:
#      State Name      County Name      City Name       BIOCO2         CH4  \
# 0       Alabama          Autauga   Autaugaville     0.000000    2.596311
# 1       Alabama          Autauga    Billingsley     0.000000    1.736851
# 2       Alabama          Autauga     Prattville  4362.405137   72.520516
# 3       Alabama   Baldwin County     Summerdale     0.000000  499.213388
# 4       Alabama   Barbour County        Eufaula     0.000000    0.055024
# ...         ...              ...            ...          ...         ...
# 7672    Wyoming     Uinta County  Mountain View     0.000000    5.354679
# 7673    Wyoming         Washakie        Worland     0.000000    0.038934
# 7674    Wyoming  Washakie County        Worland     0.000000    0.047558
# 7675    Wyoming           Weston          Osage     0.000000    0.155055
# 7676    Wyoming    Weston County      Newcastle     0.000000    3.451101
#
#               CO2        N2O
# 0     5598.875820   3.094803
# 1     3758.924495   2.072728
# 2      860.282705  31.186514
# 3        0.000000   0.000000
# 4      105.047787   0.065589
# ...           ...        ...
# 7672    36.397404   0.019948
# 7673    66.135656   0.054552
# 7674    79.295663   0.067885
# 7675   200.560474   2.955574
# 7676   269.527162   0.619373
#
# [7677 rows x 7 columns]

# %% [markdown]
# # Merging Gas data with our Final Features Dataset

# %%
## Merging with the final data set
complete_data_set = final_data_set.merge(Truncated_US_GH_gas_emissions, on=["State Name", "County Name", "City Name"])

# %%
complete_data_set
# Out:
#        State Code  County Code  Site Num State Name County Name   City Name  \
# 0               1           73        23    Alabama   Jefferson  Birmingham
# 1               1           73        23    Alabama   Jefferson  Birmingham
# 2               1           73        23    Alabama   Jefferson  Birmingham
# 3               1           73        23    Alabama   Jefferson  Birmingham
# 4               1           73        23    Alabama   Jefferson  Birmingham
# ...           ...          ...       ...        ...         ...         ...
# 30140          56           13         4    Wyoming     Fremont    Riverton
# 30141          56           13         4    Wyoming     Fremont    Riverton
# 30142          56           13         4    Wyoming     Fremont    Riverton
# 30143          56           13         4    Wyoming     Fremont    Riverton
# 30144          56           13         4    Wyoming     Fremont    Riverton
#
#         Latitude  Longitude  Date Local  Mean Temperature (F)  \
# 0      33.553056   -86.8150  2020-01-09             52.125000
# 1      33.553056   -86.8150  2020-01-10             65.750000
# 2      33.553056   -86.8150  2020-01-14             63.937500
# 3      33.553056   -86.8150  2020-01-16             58.012500
# 4      33.553056   -86.8150  2020-01-17             54.945833
# ...          ...        ...         ...                   ...
# 30140  43.024210  -108.3637  2020-09-18             59.291667
# 30141  43.024210  -108.3637  2020-09-19             61.708333
# 30142  43.024210  -108.3637  2020-10-05             56.416667
# 30143  43.024210  -108.3637  2020-10-11             50.333333
# 30144  43.024210  -108.3637  2020-11-07             54.500000
#
#        Mean Wind Direction (compass degrees)  Mean Wind Speed (knots)  \
# 0                                 137.125000                 4.904167
# 1                                 163.708333                 7.583333
# 2                                 208.916667                 3.166667
# 3                                  75.458333                 5.945833
# 4                                 105.375000                 5.491667
# ...                                      ...                      ...
# 30140                             195.166667                 2.687500
# 30141                             215.166667                 4.508333
# 30142                             224.500000                 3.720833
# 30143                             258.958333                10.012500
# 30144                             184.708333                11.091667
#
#        Elevation     Land Use       Location Setting  AQI  \
# 0          177.0   COMMERCIAL  URBAN AND CENTER CITY   56
# 1          177.0   COMMERCIAL  URBAN AND CENTER CITY   44
# 2          177.0   COMMERCIAL  URBAN AND CENTER CITY   30
# 3          177.0   COMMERCIAL  URBAN AND CENTER CITY   31
# 4          177.0   COMMERCIAL  URBAN AND CENTER CITY   34
# ...          ...          ...                    ...  ...
# 30140     1500.0  RESIDENTIAL               SUBURBAN  106
# 30141     1500.0  RESIDENTIAL               SUBURBAN   60
# 30142     1500.0  RESIDENTIAL               SUBURBAN   54
# 30143     1500.0  RESIDENTIAL               SUBURBAN   52
# 30144     1500.0  RESIDENTIAL               SUBURBAN   52
#
#                              Category Defining Parameter Defining Site  \
# 0                            Moderate              PM2.5   01-073-0023
# 1                                Good              PM2.5   01-073-0023
# 2                                Good                NO2   01-073-0023
# 3                                Good              Ozone   01-073-0023
# 4                                Good              Ozone   01-073-0023
# ...                               ...                ...           ...
# 30140  Unhealthy for Sensitive Groups              PM2.5   56-013-0004
# 30141                        Moderate              PM2.5   56-013-0004
# 30142                        Moderate              PM2.5   56-013-0004
# 30143                        Moderate               PM10   56-013-0004
# 30144                        Moderate               PM10   56-013-0004
#
#        Number of Sites Reporting  BIOCO2         CH4         CO2       N2O
# 0                              9     0.0  194.591845  145.217054  0.555493
# 1                              9     0.0  194.591845  145.217054  0.555493
# 2                              9     0.0  194.591845  145.217054  0.555493
# 3                              9     0.0  194.591845  145.217054  0.555493
# 4                              8     0.0  194.591845  145.217054  0.555493
# ...                          ...     ...         ...         ...       ...
# 30140                          5     0.0    9.998634  167.363388  0.091191
# 30141                          4     0.0    9.998634  167.363388  0.091191
# 30142                          4     0.0    9.998634  167.363388  0.091191
# 30143                          4     0.0    9.998634  167.363388  0.091191
# 30144                          4     0.0    9.998634  167.363388  0.091191
#
# [30145 rows x 24 columns]

# %%
# Non-zero count for each column
np.count_nonzero(complete_data_set, axis=0)
# Out:
# array([30145, 30145, 30145, 30145, 30145, 30145, 30145, 30145, 30145,
#        30145, 30145, 30145, 28016, 30145, 30145, 28558, 30145, 30145,
#        30145, 30145,  7076, 29787, 28599, 28421])

# %% [markdown]
# ## For this final aggregated dataset the BIOCO2, CH4, CO2, and N2O average daily emissions non-zero counts are 7076, 29787, 28599, and 28421, respectively. These values seem reasonable but if the lower values for BIOCO2 cause issues then we can remove that feature.

# %% [markdown]
# ## From this EDA our final dataset is complete_data_set, and has the following features: State Name, County Name, City Name, Mean Temperature (F), Mean Wind Direction (compass degrees), Mean Wind Speed (knots), Elevation, Land Use, Location Setting, BIOCO2, CH4, CO2, and N2O. The dataset also contains the AQI which is what we will be trying to predict, along with some other columns which can be considered meta data.
#
# ## If time permits precipitation from the daily_global_weather_2020 should be added.
